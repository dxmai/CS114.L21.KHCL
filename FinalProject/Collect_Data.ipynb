# %% [markdown]
# <a href="https://colab.research.google.com/github/dxmai/CS114.L21.KHCL/blob/main/FinalProject/Collect_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Trang naturalnews.com

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.naturalnews.com/all-posts.html'

        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.f-tabbed-list-content'):
            yield {
                'headline': post.css('h2::text').get(),
                'article_link': post.css('h2 a::attr(href)').get(),
                'is_fake': 1
            }

        next_page = response.css('.pagination-next a::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
newnatural = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/FinalProject/Dataset/naturalnews.json')
newnatural
# Out:
#                                                 headline  ... is_fake
# 0      SNITCH SOCIETY: Biden calls on Americans to be...  ...       1
# 1      Who are the “unindicted co-conspirators” in Ja...  ...       1
# 2      Tucker: Jan. 6 “insurrection” organizers were ...  ...       1
# 3      Just two investment firms – Vanguard and Black...  ...       1
# 4      Since Covid-19 vaccines are said to be free fo...  ...       1
# ...                                                  ...  ...     ...
# 34639  EXCLUSIVE: Health Ranger launches new independ...  ...       1
# 34640  Pro-abortion activists, college students incre...  ...       1
# 34641  Why does the mainstream media censor citizen s...  ...       1
# 34642  Flashback: Local pharmacies donate free vitami...  ...       1
# 34643  Exploring the anti-inflammatory properties of ...  ...       1
#
# [34644 rows x 3 columns]

# %% [markdown]
# ##Trang zerohedge.com

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.zerohedge.com/'

        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.Article_mobileNonSticky__PmGNH'):
            yield {
                'headline': post.css('h2::text').get(),
                'article_link': 'https://www.zerohedge.com/' + post.css('h2 a::attr(href)').get(),
                'is_fake': 1
            }

        next_page = response.css('a.SimplePaginator_next__15okP::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
zerohedge = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/FinalProject/Dataset/zerohedge.json')
zerohedge
# Out:
#                                                headline  ... is_fake
# 0     Jeff Bezos-Backed Company To Build Fusion Plan...  ...       1
# 1     Finding New Ways To Cool Data Centers Is Big T...  ...       1
# 2      What If The Mainstream Media Had Told The Truth?  ...       1
# 3     Manchester Arena Bombing Inquiry Finds Securit...  ...       1
# 4     Buy In Scotland, Rent In London: Britain's Pos...  ...       1
# ...                                                 ...  ...     ...
# 1554  Furious China Says It "Expelled" US Destroyer ...  ...       1
# 1555  Oil Prices Extend Slide As Iran Claims Sanctio...  ...       1
# 1556  'The Squad' Almost Derails Democrats' Capitol ...  ...       1
# 1557  Bitcoin, Big-Tech, Bullion, & Bonds Bounce As ...  ...       1
# 1558  Cathie Wood's Explanation For The Bitcoin Cras...  ...       1
#
# [1559 rows x 3 columns]

# %% [markdown]
# ##Trang prntly.com

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://prntly.com/category/science/',
            'https://prntly.com/category/politics/',
            'https://prntly.com/category/world/europe/',
            'https://prntly.com/category/world/asia/',
            'https://prntly.com/category/world/middle-east/',
            'https://prntly.com/category/local-news/',
            'https://prntly.com/category/trade-jobs/',
            'https://prntly.com/category/immigration/'
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.entry-content-holder'):
            yield {
                'headline': post.css('h2 a::text').get(),
                'article_link': post.css('h2 a::attr(href)').get(),
                'is_fake': 1
            }

        next_page = response.css('a.next::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
prntly = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/FinalProject/Dataset/prntly.json')
prntly
# Out:
#                                               headline  ... is_fake
# 0    Hypocrite Trash Colorado Gov Catches Covid-19,...  ...       1
# 1    While The Media Almost Started A Race War This...  ...       1
# 2    Coronavirus has all the charactistics of a sup...  ...       1
# 3    BREAKING: Coronavirus Infected SPIKE In South ...  ...       1
# 4    USA Leads The World In Coronavirus Recovery At...  ...       1
# ..                                                 ...  ...     ...
# 583  Trump Pressures Apple To Stop Planned Factory ...  ...       1
# 584  Fox Fans sign petition to keep conservatives o...  ...       1
# 585  Breaking: Iranians take to streets calling for...  ...       1
# 586  Prntly relaunches news outlet to counter anti-...  ...       1
# 587  President Trump’s Approval Ratings hit an all ...  ...       1
#
# [588 rows x 3 columns]

# %% [markdown]
# ##Trang thegatewaypundit.com

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.thegatewaypundit.com/'
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.tgp-post'):
            yield {
                'headline': post.css('.entry-archive-title a::text').get(),
                'article_link': post.css('.entry-archive-title a::attr(href)').get(),
                'is_fake': 1
            }

        next_page = response.css('.next a::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
thegateway = pd.read_json('drive/MyDrive/thegatewaypundit.json')
thegateway
# Out:
#                                                  headline  ... is_fake
# 0       Biden Nominee For Bureau Of Land Management Al...  ...       1
# 1       Four Healthy British Airways Pilots Die in One...  ...       1
# 2       Warning: COVID Vaccine ‘Spike Protein Shedding...  ...       1
# 3       Arizona Audit: Paper Evaluation Will Finish Ne...  ...       1
# 4       Sky News Australia Reported the Wuhan Institut...  ...       1
# ...                                                   ...  ...     ...
# 102156                                               None  ...       1
# 102157                                 USA Leaning Right!  ...       1
# 102158                          Victor! Victor! Victor!!!  ...       1
# 102159                                          Red State  ...       1
# 102160                          Welcome to Gateway Pundit  ...       1
#
# [102161 rows x 3 columns]

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.thegatewaypundit.com/'
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        isNextPage = True
        years_list = ['2021', '2020', '2019', '2018', '2017', '2016']
        for post in response.css('div.tgp-post'):
            flag = False
            year = post.css('.entry-date::text').get()
            for temp in years_list:
                if temp in year:
                    flag = True
                    break

            if flag:
                yield {
                    'headline': post.css('.entry-archive-title a::text').get(),
                    'article_link': post.css('.entry-archive-title a::attr(href)').get(),
                    'is_fake': 1
                }
            else:
                isNextPage = False

        if isNextPage:
            next_page = response.css('.next a::attr(href)').get()
            if next_page is not None:
                next_page = response.urljoin(next_page)
                yield scrapy.Request(next_page, callback=self.parse)

# %%
thegateway_notfull = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/FinalProject/Dataset/thegatewaypundit_notfull.json')
thegateway_notfull
# Out:
#                                                 headline  ... is_fake
# 0      Holy Crap! Protester in MAGA Hat Spotted Next ...  ...       1
# 1      Amazon Deletes America’s Frontline Doctor’s We...  ...       1
# 2      O*th Keep*rs Leaders Speak Out on Government P...  ...       1
# 3      Developing: Georgia Investigator’s 29 Page Ele...  ...       1
# 4      Border Patrol Captures 33 Illegal Immigrants i...  ...       1
# ...                                                  ...  ...     ...
# 53412  DRAMATIC VIDEO=> Smiling Muslim Gunman Opens F...  ...       1
# 53413  Dating Site Billboard “Where White People Meet...  ...       1
# 53414  Islamic State Fighters Strap Bomb on 4 Year-Ol...  ...       1
# 53415  Actress Lena Dunham Slams Bill Cosby Over Rape...  ...       1
# 53416  UNBELIEVABLE: House Dems Push America’s FIRST ...  ...       1
#
# [53417 rows x 3 columns]
