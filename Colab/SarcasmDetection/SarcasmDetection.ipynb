# %% [markdown]
# <a href="https://colab.research.google.com/github/dxmai/CS114.L21.KHCL/blob/main/Colab/SarcasmDetection/SarcasmDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Cài đặt và sử dụng scrapy
#
# Tham khảo tại:
#
# https://www.youtube.com/watch?v=ALizgnSFTwQ
#
# https://docs.scrapy.org/en/latest/intro/tutorial.html

# %% [markdown]
# Những câu lệnh chạy trên terminal:
#
# * Cài đặt scrapy: **pip install scrapy**
# * Tạo project: **scrapy startproject tutorial**
# * Tạo 1 file .py với tên là 'spider1'

# %%
import scrapy

class NewsSpider(scrapy.Spider):
    name = "news"
    def start_requests(self):
        urls = [
            'https://www.thebeaverton.com/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.medium-7'):
            yield {
                'title': post.css('.post-title a::text').get(),
                'link': post.css('.post-title a::attr(href)').get(),
                'label': 1
            }
        next_page = response.css('a.next::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
#
# **scrapy crawl news -o thebeaverton.json**

# %%
import pandas as pd
import json

data = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/thebearverton.json')
data
# Out:
#                                                   title  ... label
# 0            Natural deodorant deemed a waste of nature  ...     1
# 1     Neighbour’s little library features little cre...  ...     1
# 2     5 ways to explain the Habs’ success without ad...  ...     1
# 3     Hero cat bravely saves owner from being in bat...  ...     1
# 4     “This isn’t Canada” says man who has said “thi...  ...     1
# ...                                                 ...  ...   ...
# 7773  Jimmy’s Web Site Company to drop support for I...  ...     1
# 7774                Mars society treated to rare thrill  ...     1
# 7775                                 Messier a LEGO man  ...     1
# 7776  Ex-girlfriends reunites with ex-boyfriend usin...  ...     1
# 7777  Girlfriend breaks up with boyfriend using emot...  ...     1
#
# [7778 rows x 3 columns]

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.theonion.com/local',
            'https://www.theonion.com/breaking-news/news-in-brief',
            'https://www.theonion.com/entertainment/magazine',
            'https://www.theonion.com/politics/news-in-brief',
            'https://www.theonion.com/sports/basketball',
            'https://www.theonion.com/sports/football',
            'https://www.theonion.com/sports/baseball',
            'https://www.theonion.com/sports/hockey',
            'https://www.theonion.com/sports/golf',
            'https://www.theonion.com/sports/horse-racing'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.cw4lnv-5'):
            yield {
                'title': post.css('h2::text').get(),
                'link': post.css('a::attr(href)').get(),
                'label': 1
            }

        next_page = response.css('a.next-button::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
#
# **scrapy crawl news -o theonion.json**

# %%
data2 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/theonion.json')
data2
# Out:
#                                                    title  ... label
# 0      Man Emerges From Pandemic With Spine Contorted...  ...     1
# 1      Benihana Asks Diners To Surrender Their Phones...  ...     1
# 2      Desperate Employer Offers Basic Dignity To Inc...  ...     1
# 3      Pro-Labor Beliefs Deteriorating With Each Seco...  ...     1
# 4      Woman’s Anecdote About Boyfriend Getting Annoy...  ...     1
# ...                                                  ...  ...   ...
# 12952  Bosnian Gum company Introduces New War-Flavore...  ...     1
# 12953         Bob Dole Makes Car and Driver 10 Best List  ...     1
# 12954                 San Diego Zoo Acquires Chinese Man  ...     1
# 12955                    Pope Loses Keys to Vatican City  ...     1
# 12956  Cholera Outbreak Makes Americans Glad They Don...  ...     1
#
# [12957 rows x 3 columns]

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.betootaadvocate.com/category/breaking-news/',
            'https://www.betootaadvocate.com/category/advocate-in-focus/',
            'https://www.betootaadvocate.com/category/entertainment/',
            'https://www.betootaadvocate.com/category/uncategorized/',
            'https://www.betootaadvocate.com/category/humans-of-betoota/',
            'https://www.betootaadvocate.com/category/world-news/'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        for post in response.css('div.item-details'):
            yield {
                'headline': post.css('.entry-title a::text').get(),
                'article_link': post.css('.entry-title a::attr(href)').get(),
                'is_sarcastic': 1
            }

        next_page = response.css('.page-nav a::attr(href)')[-1].get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
#
# **scrapy crawl news -o thebetootaadvocate.json**

# %%
data3 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/thebetootaadvocate.json')
data3
# Out:
#                                                 headline  ... is_sarcastic
# 0      “I’d Give The Loo A Minute,” Says Dad Barely C...  ...            1
# 1      Government Considers Using Scam Emails To Tric...  ...            1
# 2      NSW Origin Squad Divided Over Whether Country ...  ...            1
# 3      Millennial Can’t Afford Home After Spending Al...  ...            1
# 4      Oh No: Best Man’s Speech Got Enough Laughs For...  ...            1
# ...                                                  ...  ...          ...
# 14604  Report: NRL Mole Definitely Should Have Said S...  ...            1
# 14605  $17 Bottle Of Pale Ale From Airport Bar Really...  ...            1
# 14606  Her Majesty’s Birthday Currently Accelerating ...  ...            1
# 14607  Ocean Alley Releases New Album Titled “Music F...  ...            1
# 14608  Local Kid Feigns Drunkenness After Learning Mu...  ...            1
#
# [14609 rows x 3 columns]

# %% [markdown]
# ##Dataset tính trong 3 năm trở lại đây

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'http://www.newsbiscuit.com/category/arts-and-entertainment/',
            'http://www.newsbiscuit.com/category/business/',
            'http://www.newsbiscuit.com/category/celebrity/',
            'http://www.newsbiscuit.com/category/crime/',
            'http://www.newsbiscuit.com/category/education/',
            'http://www.newsbiscuit.com/category/environment/',
            'http://www.newsbiscuit.com/category/faith-2/',
            'http://www.newsbiscuit.com/category/features/',
            'http://www.newsbiscuit.com/category/from-the-archives/',
            'http://www.newsbiscuit.com/category/health/',
            'http://www.newsbiscuit.com/category/isle-of-wight-news/',
            'http://www.newsbiscuit.com/category/latest/',
            'http://www.newsbiscuit.com/category/lifestyle/',
            'http://www.newsbiscuit.com/category/politics/',
            'http://www.newsbiscuit.com/category/science-and-technology/',
            'http://www.newsbiscuit.com/category/sport/',
            'http://www.newsbiscuit.com/category/stuff/',
            'http://www.newsbiscuit.com/category/uk-news/',
            'http://www.newsbiscuit.com/category/world-news/'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        years_list = ['2021', '2020', '2019', '2018']
        flag = True
        for post in response.css('div.articlebox'):
            year = post.css('time::attr(datetime)').get()
            year = year[0:4]
            if year in years_list:
                yield {
                    'headline': post.css('.col-sm-8 a::text').get(),
                    'article_link': post.css('.col-sm-8 a::attr(href)').get(),
                    'is_sarcastic': 1,
                }
            else:
                flag = False

        if flag:
            next_page = response.css('.col-xs-6 a::attr(href)').get()
            if next_page is not None:
                next_page = response.urljoin(next_page)
                yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
# **scrapy crawl news -o newsbiscuit.json**

# %%
data4 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/newsbiscuit.json')
data4
# Out:
#                                                headline  ... is_sarcastic
# 0     UK’s ‘Freedom Day’ decision passed to mixed In...  ...            1
# 1     Scandal, as teachers award higher grades to br...  ...            1
# 2     Old dogs no longer funded for trick-based educ...  ...            1
# 3     Homeschooling dad is quids-in after becoming a...  ...            1
# 4     Economy boost as schoolteacher exam prediction...  ...            1
# ...                                                 ...  ...          ...
# 2462  Money markets panic as value of limited editio...  ...            1
# 2463             Woman awakes from coma as Danny Glover  ...            1
# 2464  BBC deluged with complaints after madcap Top G...  ...            1
# 2465  BBC’s Desert Island Discs in illegal colonisat...  ...            1
# 2466  Sporting excellence linked to quality of bedti...  ...            1
#
# [2467 rows x 3 columns]

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.betootaadvocate.com/category/breaking-news/',
            'https://www.betootaadvocate.com/category/advocate-in-focus/',
            'https://www.betootaadvocate.com/category/entertainment/',
            'https://www.betootaadvocate.com/category/uncategorized/',
            'https://www.betootaadvocate.com/category/humans-of-betoota/',
            'https://www.betootaadvocate.com/category/world-news/'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        years_list = ['2021', '2020', '2019', '2018']
        flag = True
        for post in response.css('div.item-details'):
            year = post.css('time::attr(datetime)').get()
            year = year[0:4]
            if year in years_list:
                yield {
                    'headline': post.css('.entry-title a::text').get(),
                    'article_link': post.css('.entry-title a::attr(href)').get(),
                    'is_sarcastic': 1
                }
            else:
                flag = False

        if flag:
            next_page = response.css('.page-nav a::attr(href)')[-1].get()
            if next_page is not None:
                next_page = response.urljoin(next_page)
                yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
# **scrapy crawl news -o betootaadvocate.json**

# %%
data5 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/betootaadvocate.json')
data5
# Out:
#                                                headline  ... is_sarcastic
# 0     “I’d Give The Loo A Minute,” Says Dad Barely C...  ...            1
# 1     Government Considers Using Scam Emails To Tric...  ...            1
# 2     NSW Origin Squad Divided Over Whether Country ...  ...            1
# 3     Millennial Can’t Afford Home After Spending Al...  ...            1
# 4     Oh No: Best Man’s Speech Got Enough Laughs For...  ...            1
# ...                                                 ...  ...          ...
# 6540  Gabba’s Curator Drops In Section Of Vulture St...  ...            1
# 6541  Self-Described Fiscally-Conservative Socially-...  ...            1
# 6542  Palest Colleague In Workplace Also The Most Co...  ...            1
# 6543  Richard Kingsmill Handcuffs Self To Pipe And S...  ...            1
# 6544  Barnaby Joyce’s Media Pigeon Applies For Vacan...  ...            1
#
# [6545 rows x 3 columns]

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://reductress.com/news/page/1/'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        years_list = ['2021', '2020', '2019', '2018']
        for post in response.css('div.box'):
            temp = False
            year = post.css('img::attr(src)').get()
            for i in years_list:
                if i in year:
                    temp = True
                    break
            if temp:
                yield {
                    'headline': post.css('h1::text').get(),
                    'article_link': post.css('a::attr(href)').get(),
                    'is_sarcastic': 1
                }

        next_page = response.css('a.next::attr(href)').get()
        print(next_page)
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
# **scrapy crawl news -o reductress.json**

# %%
data6 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/reductress.json')
data6
# Out:
#                                               headline  ... is_sarcastic
# 0    Huge Bitch? My Niece Put ‘Pon de Replay’ on He...  ...            1
# 1    Writer Wasting Creative Energy on Drafting Fri...  ...            1
# 2    Boring Straight Guy Seen in Whole New Light Up...  ...            1
# 3    REPORT: Your Vegan Friend Doesn’t Feel Superio...  ...            1
# 4    Woman Who Almost Passed Out in the Bath Convin...  ...            1
# ..                                                 ...  ...          ...
# 595  Recently Woke Woman Thinks Everyone Should Res...  ...            1
# 596  ‘Lady Bird’ Fans Are Begging To See More Of Th...  ...            1
# 597  New Glossier Product Just Ripe Peach That You ...  ...            1
# 598  Pixar Reveals That There’s a Woman Walking to ...  ...            1
# 599  Richest Friend Just ‘Doesn’t Like To Cook’ and...  ...            1
#
# [600 rows x 3 columns]

# %%
#Chuyển dữ liệu về dataframe để dễ xử lý hơn, đổi tên cột để thể hiện ý nghĩ rõ hơn
data = pd.DataFrame.from_dict(data)
data.columns = ['headline', 'article_link', 'is_sarcastic']
data2 = pd.DataFrame.from_dict(data2)
data2.columns = ['headline', 'article_link', 'is_sarcastic']

# %% [markdown]
# Nguyễn Thị Thảo Hiền's

# %%
import scrapy


class NewsSpider(scrapy.Spider):
    name = "news"

    def start_requests(self):
        urls = [
            'https://www.thedailymash.co.uk/news',
            'https://www.thedailymash.co.uk/news/lifestyle',
            'https://www.thedailymash.co.uk/news/society',
            'https://www.thedailymash.co.uk/news/health',
            'https://www.thedailymash.co.uk/news/arts-entertainment',
            'https://www.thedailymash.co.uk/news/science-technology',
            'https://www.thedailymash.co.uk/news/business',
            'https://www.thedailymash.co.uk/news/relationships',
            'https://www.thedailymash.co.uk/politics',
            'https://www.thedailymash.co.uk/sport'
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        name = 'div.md\:mr-8'
        for post in response.css(name):
            yield {
                'headline': post.css('.-mt-1 a::text').get(),
                'article_link': 'https://www.thedailymash.co.uk' + post.css('.-mt-1 a::attr(href)').get(),
                'is_sarcastic': 1
            }

        next_page = response.css('a.ml-3::attr(href)').get()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %% [markdown]
# Câu lệnh chạy trên terminal:
# **scrapy crawl news -o thedailymash.json**

# %%
data4 = pd.read_json('https://raw.githubusercontent.com/dxmai/CS114.L21.KHCL/main/Colab/SarcasmDetection/Dataset/thedailymash.json')
data4
# Out:
#                                                 headline  ... is_sarcastic
# 0      School kid who didn't revise and prayed for a ...  ...            1
# 1      Pub fruit machine dreamt of being vending mach...  ...            1
# 2      Meghan to embrace British culture by carrying ...  ...            1
# 3                                          Charlie Hebdo  ...            1
# 4                                        Git of the Year  ...            1
# ...                                                  ...  ...          ...
# 10738  Campaigners Welcome Plan For Free-Range Pensio...  ...            1
# 10739  All Secrets To Be Written Down And Dumped In A...  ...            1
# 10740                                     Cock Ban Looms  ...            1
# 10741          People over 30 are grown-ups, say experts  ...            1
# 10742  Drivers Who Shoot At People From Behind The Wh...  ...            1
#
# [10743 rows x 3 columns]
